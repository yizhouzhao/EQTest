# %%
import os
import json

# %%
root_folder = "E:/Temp/TestImages"

# %%
img_lst = []

# %%
img_lst
# Out:
# [['Acknowledging_Acknowledging_-1_2',
#   [['E:/Temp/TestImages/Acknowledging_Acknowledging_-1_2/persp_0.png',
#     'E:/Temp/TestImages/Acknowledging_Acknowledging_-1_2/persp_12.png'],
#    ['E:/Temp/TestImages/Acknowledging_Acknowledging_-1_2/camera1_0.png',
#     'E:/Temp/TestImages/Acknowledging_Acknowledging_-1_2/camera1_12.png'],
#    ['E:/Temp/TestImages/Acknowledging_Acknowledging_-1_2/camera2_0.png',
#     'E:/Temp/TestImages/Acknowledging_Acknowledging_-1_2/camera2_12.png']]],
#  ['Acknowledging_Acknowledging_-1_4',
#   [['E:/Temp/TestImages/Acknowledging_Acknowledging_-1_4/persp_0.png',
#     'E:/Temp/TestImages/Acknowledging_Acknowledging_-1_4/persp_12.png'],
#    ['E:/Temp/TestImages/Acknowledging_Acknowledging_-1_4/camera1_0.png',
#     'E:/Temp/TestImages/Acknowledging_Acknowledging_-1_4/camera1_12.png'],
#    ['E:/Temp/TestImages/Acknowledging_Acknowledging_-1_4/camera2_0.png',
#     'E:/Temp/TestImages/Acknowledging_Acknowledging_-1_4/camera2_12.png']]],
# ...

# %%
for folder_name in os.listdir(root_folder):
    img_folder = root_folder + "/" + folder_name
    img_info = [[],[],[]]
    for file_name in os.listdir(img_folder):
        if file_name.startswith("persp"):
            img_info[0].append(img_folder + "/" + file_name)
        elif file_name.startswith("camera1"):
            img_info[1].append(img_folder + "/" + file_name)
        else:
            img_info[2].append(img_folder + "/" + file_name)
    img_lst.append([folder_name, img_info])

# %%
with open("E:/Temp/jsonURL.txt", 'w') as outfile:
    json.dump(img_lst, outfile)

# %%
import os

# %%
files = os.listdir("sceenshots")

# %%
for file in files:
    #file_info = file.split("_")
    print(file, file_info)
    os.rename("sceenshots/"+ file, "sceenshots/" + file[:-5] + file[-4:])
# Out:
# Annoyed0.png ['boy2', 'Tired', 'camera2', '0.png']
# Concerned0.png ['boy2', 'Tired', 'camera2', '0.png']
# Confused0.png ['boy2', 'Tired', 'camera2', '0.png']
# Curious0.png ['boy2', 'Tired', 'camera2', '0.png']
# Delight0.png ['boy2', 'Tired', 'camera2', '0.png']
# Disgust0.png ['boy2', 'Tired', 'camera2', '0.png']
# Dissatisfied0.png ['boy2', 'Tired', 'camera2', '0.png']
# Embarrased0.png ['boy2', 'Tired', 'camera2', '0.png']
# Excited0.png ['boy2', 'Tired', 'camera2', '0.png']
# Frustrated0.png ['boy2', 'Tired', 'camera2', '0.png']
# Happy0.png ['boy2', 'Tired', 'camera2', '0.png']
# Hate0.png ['boy2', 'Tired', 'camera2', '0.png']
# Madness0.png ['boy2', 'Tired', 'camera2', '0.png']
# Mock0.png ['boy2', 'Tired', 'camera2', '0.png']
# Neutral0.png ['boy2', 'Tired', 'camera2', '0.png']
# Sad0.png ['boy2', 'Tired', 'camera2', '0.png']
# Scared0.png ['boy2', 'Tired', 'camera2', '0.png']
# Surprise0.png ['boy2', 'Tired', 'camera2', '0.png']
# ...
